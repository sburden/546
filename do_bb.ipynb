# %%
# %matplotlib inline

# %%
# %pdb on
# Out:
# Automatic pdb calling has been turned ON

# %%
run bb
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# c:\users\sburden\g\546\src\bb.py in <module>()
#      84   p = dict(m=m, g=g, c=c, debug=debug, Zeno=Zeno)
#      85
# ---> 86   1/0
#      87
#      88   bb = BouncingBall()
#
# ZeroDivisionError: integer division or modulo by zero
# > c:\users\sburden\g\546\src\bb.py(86)<module>()
#      84   p = dict(m=m, g=g, c=c, debug=debug, Zeno=Zeno)
#      85
# ---> 86   1/0
#      87
#      88   bb = BouncingBall()
#
# ipdb> l
#      81   Zeno = True
#      82   Zeno = False
#      83
#      84   p = dict(m=m, g=g, c=c, debug=debug, Zeno=Zeno)
#      85
# ---> 86   1/0
#      87
#      88   bb = BouncingBall()
#      89
#      90   h  = 1e-2
#      91   rx = 1e-6
#
# ipdb> u
# > c:\anaconda2\lib\site-packages\ipython\utils\py3compat.py(278)execfile()
#     276                 filename = fname
# ...

# %%
plt.show()

# %%
len(trjs)
# Out:
# 3

# %%
trjs[-1]
# Out:
# {'j': 1,
#  'k': 2,
#  't': [1.0374558711304132],
#  'x': [array([ 0.        ,  1.94790059])]}

# %%
trjs[0].keys()
# Out:
# ['x', 'k', 'j', 't']

# %%
trjs[0]['x'][-1]
# Out:
# array([ -6.63137761e-07,  -4.47180023e+00])

# %%
trjs[1]['x'][0]
# Out:
# array([ 0.        ,  2.95138815])

# %%
-4.47*(-.66)
# Out:
# 2.9502
